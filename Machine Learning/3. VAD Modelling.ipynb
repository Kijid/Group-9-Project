# %%
# Core Libraries
import pandas as pd
import numpy as np
import gensim
import sklearn
import plotly
import pickle

# Natural Language Processing
import nltk
from gensim import corpora
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel
from gensim.utils import simple_preprocess
from sklearn.feature_extraction.text import CountVectorizer

# Machine Learning and Clustering
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering, KMeans, AffinityPropagation
from sklearn.metrics import silhouette_score, silhouette_samples

# Visualization
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# Miscellaneous
from ast import literal_eval
from scipy.spatial import distance

# Ensure gensim version is 4.3.2 and install openpyxl
# !pip install gensim==4.3.2
# !pip install openpyxl
# Out:
# Requirement already satisfied: gensim==4.3.2 in /root/venv/lib/python3.9/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (1.23.4)
# Requirement already satisfied: scipy>=1.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (1.9.3)
# Requirement already satisfied: smart-open>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (5.2.1)
# Requirement already satisfied: openpyxl in /root/venv/lib/python3.9/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /root/venv/lib/python3.9/site-packages (from openpyxl) (1.1.0)

# %%
vad = pd.read_excel('/work/GitHub_ML_Deepnote/Machine Learning/3. VAD/vad.xlsx', index_col=0, engine='openpyxl')
word_level_df = pd.read_csv('/work/GitHub_ML_Deepnote/Machine Learning/2. Cleaning & Pre-processing/word_level_df.csv', encoding='utf-8', index_col=0)
sentence_level_df = pd.read_csv('/work/GitHub_ML_Deepnote/Machine Learning/2. Cleaning & Pre-processing/sentence_level_df.csv',  encoding='utf-8', index_col = 0)

# %%
# Extract lemmas from the 'lemmas' column in word_level_df
corpus_words = [literal_eval(lemmas) for lemmas in word_level_df['lemmas'].values]

# Save corpus_words as a pickle file
with open('/work/GitHub_ML_Deepnote/Machine Learning/3. VAD/corpus_words.pkl', 'wb') as file:
    pickle.dump(corpus_words, file)

# Flatten the list of lemmas
corpus_flat_lemmas = [lemma for sublist in corpus_words for lemma in sublist]

# %%
corpus_words = []
corpus_emo = []
corpus_noVAD = [] 
#another way we can overview what words haven't been matched with a VAD score

for i in corpus_flat_lemmas:
    if i in vad.index:
        corpus_emo.append(vad.loc[i])
        corpus_words.append(i)
    else:
        corpus_noVAD.append(i)

# %%
corpus_vad = pd.DataFrame(corpus_emo, index = corpus_words)

# %% [markdown]
# ### Utalising word2vec - ignore this bit for now and scroll to visualisations

# %%
Trump_model = gensim.models.Word2Vec(trump_lemmas, min_count= 20, vector_size = 300)
Trump_model.wv['american']
Trump_vocab = Trump_model.wv.index_to_key
Trump_vectors = [Trump_model.wv[i] for i in Trump_vocab]

Trump_df = pd.DataFrame(Trump_vectors)
Trump_df.columns = [str(i) for i in Trump_df.columns]

pca = PCA(n_components = 3)
comps_1 = pca.fit_transform(Trump_vectors)
pc_df_1 = pd.DataFrame(data = comps_1, columns = ['Principal Component '+str(i) for i in range(1, comps_1.shape[1]+1)])
Trump_df = pd.concat([Trump_df, pc_df_1], axis = 1)
Trump_df.index = Trump_vocab

# %%
#Silhoutte method to identify optimal amount of clusters. This method is also indicating 4.

#range of clusters to test
range_n_clusters = range(2, 10)

# Converting dataframe to numpy array for clustering
X = np.array(Trump_df)

# Initialising list to store silhouette scores for each number of clusters
silhouette_scores = []

# Iterating over set range of clusters and calculating silhouette score
for n_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=n_clusters, random_state=0, n_init= 10)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_avg = silhouette_score(X, cluster_labels)
    silhouette_scores.append(silhouette_avg)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)

# Clustering our data to see what groups together

kmeans = KMeans(n_clusters=5, random_state=0, n_init= 10 ).fit(cluster_df)

#Adding relevant values to our dataframe
Trump_df['clusters_knn'] = [str(i) for i in kmeans.labels_]

#Viewing a single cluster to observe in greater detail
TCluster_0= Trump_df.loc[Trump_df['clusters_knn'] == '0']
TCluster_1= Trump_df.loc[Trump_df['clusters_knn'] == '1']
TCluster_2= Trump_df.loc[Trump_df['clusters_knn'] == '2']
TCluster_3= Trump_df.loc[Trump_df['clusters_knn'] == '3']
TCluster_4= Trump_df.loc[Trump_df['clusters_knn'] == '4']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [88], line 1
# ----> 1 cluster_df = pd.DataFrame(cluster_vectors)
#       2 #Silhoutte method to identify optimal amount of clusters. This method is also indicating 4.
#       3
#       4 #range of clusters to test
#       5 range_n_clusters = range(2, 10)
#
# NameError: name 'cluster_vectors' is not defined

# %% [markdown]
# ### Visualisations currently..

# %%
X = corpus_vad[['valence', 'arousal', 'dominance']].values

# Specify the number of clusters
n_clusters = 6  # Adjust this number based on your preference

# Perform K-means clustering
kmeans = KMeans(n_clusters=n_clusters, random_state=42)
corpus_vad['Cluster'] = kmeans.fit_predict(X)

# %%
import plotly.express as px

# Sample data
corpus_vad_s = corpus_vad.sample(1000)

fig = px.scatter_3d(corpus_vad_s, x='valence', y='arousal', z='dominance', color='Cluster', hover_data=[corpus_vad_s.index],
                    color_discrete_sequence=['yellow', 'green', 'blue', 'red'])

fig.update_traces(marker=dict(size=5, line=dict(width=2, color='DarkSlateGrey')), selector=dict(mode='markers'))

# Hide the color bar
fig.update_layout(coloraxis_showscale=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="50a06475-ed5c-4bd4-a930-d82a3b788cda" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50a06475-ed5c-4bd4-a930-d82a3b788cda")) {                    Plotly.newPlot(                        "50a06475-ed5c-4bd4-a930-d82a3b788cda",                        [{"customdata":[["seriously"],["one"],["condition"],["development"],["goal"],["war"],["state"],["would"],["end"],["exist"],["issue"],["human"],["scenario"],["happily"],["worry"],["work"],["simple"],["problem"],["technology"],["top"],["legal"],["come"],["make"],["prompt"],["strategy"],["necessarily"],["preference"],["ask"],["goal"],["aware"],["news"],["mean"],["human"],["eliminate"],["consciousness"],["sell"],["bee"],["work"],["thing"],["replacement"],["find"],["want"],["ex"],["one"],["want"],["resentment"],["dream"],["talk"],["portray"],["good"],["seemingly"],["go"],["conscious"],["consciousness"],["integrate"],["psychological"],["desperate"],["present"],["house"],["think"],["actually"],["go"],["consciousness"],["life"],["well"],["begin"],["world"],["like"],["get"],["container"],["miss"],["small"],["see"],["react"],["behavior"],["happen"],["instant"],["love"],["massive"],["combination"],["prime"],["bag"],["people"],["care"],["work"],["person"],["suffer"],["tool"],["view"],["previously"],["intelligence"],["sort"],["design"],["concept"],["real"],["obviously"],["point"],["reference"],["consciousness"],["van"],["world"],["problem"],["shift"],["behavior"],["chess"],["eye"],["power"],["fast"],["feel"],["well"],["human"],["thing"],["well"],["opponent"],["genetic"],["mystery"],["game"],["rogue"],["integration"],["colleague"],["think"],["would"],["think"],["lifetime"],["humanity"],["grid"],["fact"],["see"],["stay"],["dissolve"],["psychological"],["valley"],["strategy"],["try"],["think"],["universal"],["king"],["assumption"],["believe"],["people"],["travel"],["solve"],["example"],["legacy"],["put"],["robot"],["world"],["effect"],["humanity"],["good"],["star"],["human"],["smart"],["fuck"],["need"],["engineer"],["right"],["like"],["maintain"],["easily"],["communication"],["ongoing"],["even"],["sale"],["recommend"],["humanity"],["impede"],["fact"],["switch"],["extend"],["constantly"],["aspect"],["window"],["life"],["fear"],["afraid"],["job"],["completely"],["biological"],["work"],["suppose"],["associate"],["say"],["human"],["manner"],["bunch"],["mechanism"],["would"],["assemble"],["take"],["think"],["area"],["hypothetical"],["world"],["intelligence"],["argue"],["human"],["far"],["example"],["guess"],["term"],["cause"],["system"],["chance"],["factory"],["go"],["common"],["give"],["ability"],["conscious"],["part"],["simulation"],["robot"],["make"],["let"],["money"],["flesh"],["see"],["matter"],["pharmaceutical"],["easy"],["let"],["stock"],["level"],["planet"],["real"],["consciousness"],["yes"],["make"],["huge"],["make"],["notion"],["know"],["alive"],["sorry"],["know"],["far"],["even"],["machine"],["tech"],["person"],["response"],["exchange"],["like"],["mind"],["side"],["point"],["service"],["alive"],["artificial"],["think"],["thing"],["would"],["sure"],["human"],["perfectly"],["care"],["purchase"],["point"],["project"],["great"],["fuck"],["discover"],["alive"],["want"],["well"],["short"],["watch"],["negative"],["consciousness"],["conversion"],["conscious"],["theory"],["reach"],["deal"],["natural"],["excite"],["kill"],["thought"],["knowledge"],["effective"],["paper"],["start"],["step"],["human"],["far"],["intention"],["thing"],["clip"],["conscious"],["idea"],["see"],["unpredictable"],["resent"],["fact"],["bad"],["stupid"],["logic"],["one"],["reason"],["turn"],["population"],["simple"],["smart"],["capable"],["position"],["follow"],["way"],["even"],["space"],["argue"],["two"],["human"],["thought"],["life"],[ ...

# %%
# Saving the 3D scatter plot as an HTML file
fig.write_html('/work/GitHub_ML_Deepnote/Machine Learning/3. VAD/vad_3d_plot.html')

# %%
# Sample data
corpus_vad_s = corpus_vad.sample(1000)

# Plot 1: Valence vs Dominance
fig1 = px.scatter(corpus_vad_s, x='valence', y='dominance', color='Cluster', hover_data=[corpus_vad_s.index],
                  color_discrete_sequence=['yellow', 'green', 'blue', 'red'])

fig1.update_traces(marker=dict(size=5, line=dict(width=0)), selector=dict(mode='markers'))

# Plot 2: Arousal vs Valence
fig2 = px.scatter(corpus_vad_s, x='arousal', y='valence', color='Cluster', hover_data=[corpus_vad_s.index],
                  color_discrete_sequence=['yellow', 'green', 'blue', 'red'])

fig2.update_traces(marker=dict(size=5, line=dict(width=0)), selector=dict(mode='markers'))

# Plot 3: Arousal vs Dominance
fig3 = px.scatter(corpus_vad_s, x='arousal', y='dominance', color='Cluster', hover_data=[corpus_vad_s.index],
                  color_discrete_sequence=['yellow', 'green', 'blue', 'red'])

fig3.update_traces(marker=dict(size=5, line=dict(width=0)), selector=dict(mode='markers'))

# Show the plots
fig1.show()
fig2.show()
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="76a65a73-9253-47d8-b455-ebca4db0e69e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76a65a73-9253-47d8-b455-ebca4db0e69e")) {                    Plotly.newPlot(                        "76a65a73-9253-47d8-b455-ebca4db0e69e",                        [{"customdata":[["take"],["pick"],["change"],["issue"],["rich"],["prompt"],["society"],["free"],["guess"],["make"],["represent"],["investor"],["boy"],["would"],["one"],["book"],["fund"],["state"],["good"],["solar"],["consciousness"],["wish"],["awareness"],["pursuit"],["safe"],["find"],["respond"],["need"],["altogether"],["new"],["human"],["past"],["canvas"],["sense"],["assumption"],["concern"],["people"],["say"],["fact"],["sub"],["discussion"],["cell"],["body"],["dumb"],["know"],["would"],["alter"],["ask"],["take"],["face"],["end"],["thought"],["money"],["wrong"],["process"],["one"],["presumably"],["possible"],["prompt"],["human"],["win"],["try"],["make"],["even"],["technology"],["save"],["maybe"],["ask"],["definitely"],["people"],["happen"],["tool"],["suck"],["way"],["people"],["coordinate"],["would"],["concept"],["practical"],["agent"],["stuff"],["rich"],["away"],["basic"],["think"],["know"],["prime"],["intelligent"],["owner"],["thing"],["way"],["way"],["naturally"],["pension"],["begin"],["instruction"],["desperate"],["obtain"],["consciousness"],["like"],["probability"],["thing"],["sell"],["use"],["income"],["make"],["pharmaceutical"],["robot"],["resent"],["tendency"],["universe"],["call"],["pretty"],["legacy"],["development"],["aware"],["use"],["come"],["great"],["like"],["thing"],["believe"],["human"],["take"],["gain"],["scenario"],["intelligent"],["yes"],["late"],["think"],["operate"],["go"],["talk"],["pretty"],["predict"],["mention"],["capacity"],["alive"],["high"],["literally"],["progress"],["question"],["print"],["human"],["equivalent"],["industry"],["please"],["remainder"],["display"],["charge"],["overthrow"],["think"],["track"],["third"],["charge"],["game"],["subject"],["creativity"],["deeply"],["slowly"],["ridiculous"],["human"],["look"],["use"],["believe"],["cause"],["space"],["health"],["good"],["narrative"],["think"],["opinion"],["design"],["close"],["self"],["thing"],["paper"],["ex"],["end"],["ecosystem"],["require"],["make"],["weapon"],["make"],["mother"],["valley"],["world"],["style"],["supporter"],["time"],["despite"],["reply"],["life"],["information"],["path"],["trust"],["attack"],["train"],["bet"],["signal"],["protein"],["space"],["need"],["eager"],["brain"],["method"],["die"],["need"],["attitude"],["high"],["thing"],["perpetual"],["right"],["improve"],["time"],["align"],["threat"],["absolutely"],["buy"],["diversity"],["would"],["dysfunction"],["cut"],["proposal"],["money"],["class"],["method"],["would"],["leave"],["behavior"],["form"],["unknown"],["theory"],["see"],["people"],["lead"],["great"],["ask"],["market"],["example"],["discussion"],["prospect"],["machine"],["consciousness"],["era"],["opponent"],["control"],["ill"],["intelligence"],["trait"],["fail"],["special"],["curious"],["proposal"],["decision"],["focus"],["necessary"],["example"],["near"],["brain"],["toy"],["point"],["shrink"],["undertake"],["come"],["spend"],["extent"],["point"],["fear"],["able"],["goal"],["purchase"],["tube"],["plan"],["thing"],["set"],["effect"],["obvious"],["original"],["general"],["reach"],["deny"],["early"],["rental"],["verify"],["direct"],["near"],["would"],["good"],["seemingly"],["route"],["try"],["proof"],["emotional"],["power"],["conscious"],["acquisition"],["research"],["mention"],["order"],["factory"],["impossible"],["give"],["would"],["come"],["eventually"],["scale"],["thing"],["week"],["would"],["literally"],["capable"],["train"],["people"],["plant"],["research"],["even"],["rep ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="a4355eb3-2c7d-48b5-8824-cd51a5bb072a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4355eb3-2c7d-48b5-8824-cd51a5bb072a")) {                    Plotly.newPlot(                        "a4355eb3-2c7d-48b5-8824-cd51a5bb072a",                        [{"customdata":[["take"],["pick"],["change"],["issue"],["rich"],["prompt"],["society"],["free"],["guess"],["make"],["represent"],["investor"],["boy"],["would"],["one"],["book"],["fund"],["state"],["good"],["solar"],["consciousness"],["wish"],["awareness"],["pursuit"],["safe"],["find"],["respond"],["need"],["altogether"],["new"],["human"],["past"],["canvas"],["sense"],["assumption"],["concern"],["people"],["say"],["fact"],["sub"],["discussion"],["cell"],["body"],["dumb"],["know"],["would"],["alter"],["ask"],["take"],["face"],["end"],["thought"],["money"],["wrong"],["process"],["one"],["presumably"],["possible"],["prompt"],["human"],["win"],["try"],["make"],["even"],["technology"],["save"],["maybe"],["ask"],["definitely"],["people"],["happen"],["tool"],["suck"],["way"],["people"],["coordinate"],["would"],["concept"],["practical"],["agent"],["stuff"],["rich"],["away"],["basic"],["think"],["know"],["prime"],["intelligent"],["owner"],["thing"],["way"],["way"],["naturally"],["pension"],["begin"],["instruction"],["desperate"],["obtain"],["consciousness"],["like"],["probability"],["thing"],["sell"],["use"],["income"],["make"],["pharmaceutical"],["robot"],["resent"],["tendency"],["universe"],["call"],["pretty"],["legacy"],["development"],["aware"],["use"],["come"],["great"],["like"],["thing"],["believe"],["human"],["take"],["gain"],["scenario"],["intelligent"],["yes"],["late"],["think"],["operate"],["go"],["talk"],["pretty"],["predict"],["mention"],["capacity"],["alive"],["high"],["literally"],["progress"],["question"],["print"],["human"],["equivalent"],["industry"],["please"],["remainder"],["display"],["charge"],["overthrow"],["think"],["track"],["third"],["charge"],["game"],["subject"],["creativity"],["deeply"],["slowly"],["ridiculous"],["human"],["look"],["use"],["believe"],["cause"],["space"],["health"],["good"],["narrative"],["think"],["opinion"],["design"],["close"],["self"],["thing"],["paper"],["ex"],["end"],["ecosystem"],["require"],["make"],["weapon"],["make"],["mother"],["valley"],["world"],["style"],["supporter"],["time"],["despite"],["reply"],["life"],["information"],["path"],["trust"],["attack"],["train"],["bet"],["signal"],["protein"],["space"],["need"],["eager"],["brain"],["method"],["die"],["need"],["attitude"],["high"],["thing"],["perpetual"],["right"],["improve"],["time"],["align"],["threat"],["absolutely"],["buy"],["diversity"],["would"],["dysfunction"],["cut"],["proposal"],["money"],["class"],["method"],["would"],["leave"],["behavior"],["form"],["unknown"],["theory"],["see"],["people"],["lead"],["great"],["ask"],["market"],["example"],["discussion"],["prospect"],["machine"],["consciousness"],["era"],["opponent"],["control"],["ill"],["intelligence"],["trait"],["fail"],["special"],["curious"],["proposal"],["decision"],["focus"],["necessary"],["example"],["near"],["brain"],["toy"],["point"],["shrink"],["undertake"],["come"],["spend"],["extent"],["point"],["fear"],["able"],["goal"],["purchase"],["tube"],["plan"],["thing"],["set"],["effect"],["obvious"],["original"],["general"],["reach"],["deny"],["early"],["rental"],["verify"],["direct"],["near"],["would"],["good"],["seemingly"],["route"],["try"],["proof"],["emotional"],["power"],["conscious"],["acquisition"],["research"],["mention"],["order"],["factory"],["impossible"],["give"],["would"],["come"],["eventually"],["scale"],["thing"],["week"],["would"],["literally"],["capable"],["train"],["people"],["plant"],["research"],["even"],["rep ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="c43b52a0-4f4c-4ae3-895f-d3d8fe56cca3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c43b52a0-4f4c-4ae3-895f-d3d8fe56cca3")) {                    Plotly.newPlot(                        "c43b52a0-4f4c-4ae3-895f-d3d8fe56cca3",                        [{"customdata":[["take"],["pick"],["change"],["issue"],["rich"],["prompt"],["society"],["free"],["guess"],["make"],["represent"],["investor"],["boy"],["would"],["one"],["book"],["fund"],["state"],["good"],["solar"],["consciousness"],["wish"],["awareness"],["pursuit"],["safe"],["find"],["respond"],["need"],["altogether"],["new"],["human"],["past"],["canvas"],["sense"],["assumption"],["concern"],["people"],["say"],["fact"],["sub"],["discussion"],["cell"],["body"],["dumb"],["know"],["would"],["alter"],["ask"],["take"],["face"],["end"],["thought"],["money"],["wrong"],["process"],["one"],["presumably"],["possible"],["prompt"],["human"],["win"],["try"],["make"],["even"],["technology"],["save"],["maybe"],["ask"],["definitely"],["people"],["happen"],["tool"],["suck"],["way"],["people"],["coordinate"],["would"],["concept"],["practical"],["agent"],["stuff"],["rich"],["away"],["basic"],["think"],["know"],["prime"],["intelligent"],["owner"],["thing"],["way"],["way"],["naturally"],["pension"],["begin"],["instruction"],["desperate"],["obtain"],["consciousness"],["like"],["probability"],["thing"],["sell"],["use"],["income"],["make"],["pharmaceutical"],["robot"],["resent"],["tendency"],["universe"],["call"],["pretty"],["legacy"],["development"],["aware"],["use"],["come"],["great"],["like"],["thing"],["believe"],["human"],["take"],["gain"],["scenario"],["intelligent"],["yes"],["late"],["think"],["operate"],["go"],["talk"],["pretty"],["predict"],["mention"],["capacity"],["alive"],["high"],["literally"],["progress"],["question"],["print"],["human"],["equivalent"],["industry"],["please"],["remainder"],["display"],["charge"],["overthrow"],["think"],["track"],["third"],["charge"],["game"],["subject"],["creativity"],["deeply"],["slowly"],["ridiculous"],["human"],["look"],["use"],["believe"],["cause"],["space"],["health"],["good"],["narrative"],["think"],["opinion"],["design"],["close"],["self"],["thing"],["paper"],["ex"],["end"],["ecosystem"],["require"],["make"],["weapon"],["make"],["mother"],["valley"],["world"],["style"],["supporter"],["time"],["despite"],["reply"],["life"],["information"],["path"],["trust"],["attack"],["train"],["bet"],["signal"],["protein"],["space"],["need"],["eager"],["brain"],["method"],["die"],["need"],["attitude"],["high"],["thing"],["perpetual"],["right"],["improve"],["time"],["align"],["threat"],["absolutely"],["buy"],["diversity"],["would"],["dysfunction"],["cut"],["proposal"],["money"],["class"],["method"],["would"],["leave"],["behavior"],["form"],["unknown"],["theory"],["see"],["people"],["lead"],["great"],["ask"],["market"],["example"],["discussion"],["prospect"],["machine"],["consciousness"],["era"],["opponent"],["control"],["ill"],["intelligence"],["trait"],["fail"],["special"],["curious"],["proposal"],["decision"],["focus"],["necessary"],["example"],["near"],["brain"],["toy"],["point"],["shrink"],["undertake"],["come"],["spend"],["extent"],["point"],["fear"],["able"],["goal"],["purchase"],["tube"],["plan"],["thing"],["set"],["effect"],["obvious"],["original"],["general"],["reach"],["deny"],["early"],["rental"],["verify"],["direct"],["near"],["would"],["good"],["seemingly"],["route"],["try"],["proof"],["emotional"],["power"],["conscious"],["acquisition"],["research"],["mention"],["order"],["factory"],["impossible"],["give"],["would"],["come"],["eventually"],["scale"],["thing"],["week"],["would"],["literally"],["capable"],["train"],["people"],["plant"],["research"],["even"],["rep ...

# %%
# Save the plots as HTML files
fig1.write_html('/work/GitHub_ML_Deepnote/Machine Learning/3. VAD/vad_plot_valence_dominance.html')
fig2.write_html('/work/GitHub_ML_Deepnote/Machine Learning/3. VAD/vad_plot_arousal_valence.html')
fig3.write_html('/work/GitHub_ML_Deepnote/Machine Learning/3. VAD/vad_plot_arousal_dominance.html')

# %% [markdown]
# ### feel like clusters like below will be possible if i apply word2vec model as basis again

# %%
T_words_cluster_0 = list(TCluster_0.index)

# Filter Trump_vad to only include words in TCluster_0
Trump_vad_cluster_0 = Trump_vad[Trump_vad.index.isin(T_words_cluster_0)]

# Create scatter plot of VAD visualizations for words in TCluster_0
fig = px.scatter_3d(Trump_vad_cluster_0, x='valence', y='arousal', z='dominance', 
                    color=Trump_vad_cluster_0.index, hover_data=[Trump_vad_cluster_0.index],
                    color_discrete_sequence=['red'])
fig.update_traces(marker=dict(size=5, line=dict(width=2, color='DarkSlateGrey')),
                  selector=dict(mode='markers'))
fig.update_layout(title='Trump VAD Values for Cluster 0')
fig.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f64215d6-debc-46bd-b273-63565459a66d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
