# %% [markdown]
# ## Requirements

# %%
# !pip install gensim==4.3.2
# Out:
# Requirement already satisfied: gensim==4.3.2 in /root/venv/lib/python3.9/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (1.23.4)
# Requirement already satisfied: smart-open>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (5.2.1)
# Requirement already satisfied: scipy>=1.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (1.9.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Core Libraries & Packages

# %%
# Core Libraries
import pandas as pd
import numpy as np
import gensim
import sklearn
import plotly
import pickle

# Natural Language Processing
import nltk
from gensim import corpora
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel
from gensim.utils import simple_preprocess
from sklearn.feature_extraction.text import CountVectorizer

# Machine Learning and Clustering
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering, KMeans, AffinityPropagation
from sklearn.metrics import silhouette_score, silhouette_samples

# Visualization
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# Miscellaneous
from ast import literal_eval
from scipy.spatial import distance

# Ensure gensim version is 4.3.2 and install openpyxl
# !pip install gensim==4.3.2
# !pip install openpyxl
# Out:
# Requirement already satisfied: gensim==4.3.2 in /root/venv/lib/python3.9/site-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (1.23.4)
# Requirement already satisfied: smart-open>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (5.2.1)
# Requirement already satisfied: scipy>=1.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (1.9.3)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 25.4 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## VAD Analysis

# %%
vad = pd.read_excel('/work/GitHub_ML_Deepnote/Machine Learning/4. VAD/vad.xlsx', index_col=0, engine='openpyxl')

# %%
# Specify the path to the pickle file
pickle_file_path = '/work/GitHub_ML_Deepnote/Machine Learning/3. Word2vec /corpus_words.pkl'

# Load the pickled object
with open(pickle_file_path, 'rb') as file:
    corpus_words = pickle.load(file)

# Flatten the list of lemmas
corpus_flat_lemmas = [lemma for sublist in corpus_words for lemma in sublist]

# %%
# Original code: count.corpus_words
# Fixed Code:
len(corpus_words)
# Out:
# 116174

# %%
corpus_words = []
corpus_emo = []
corpus_noVAD = [] 
#another way we can overview what words haven't been matched with a VAD score

for i in corpus_flat_lemmas:
    if i in vad.index:
        corpus_emo.append(vad.loc[i])
        corpus_words.append(i)
    else:
        corpus_noVAD.append(i)

# %%
corpus_vad = pd.DataFrame(corpus_emo, index = corpus_words)

# %%
# Select features for clustering
X = corpus_vad[['valence', 'arousal', 'dominance']].values

# %%
# Elbow method to identify the optimal number of clusters
inertia = []
K = range(1, 11)

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

# Plot the elbow method graph
plt.figure(figsize=(10, 6))
plt.plot(K, inertia, marker='o')
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.xticks(np.arange(1, 11, 1))
plt.grid(True)
plt.show()

# %%
# Based on the elbow method, choose the optimal number of clusters
optimal_clusters = 5  # Replace with the number you determine from the graph

# Perform K-means clustering with the optimal number of clusters
kmeans = KMeans(n_clusters=optimal_clusters, random_state=42)
corpus_vad['Cluster'] = kmeans.fit_predict(X)

# %% [markdown]
# ### old visual

# %%
# Sample data
corpus_vad_s = corpus_vad.sample(2000)

fig = px.scatter_3d(corpus_vad_s, x='valence', y='arousal', z='dominance', color='Cluster', hover_data=[corpus_vad_s.index],
                    color_discrete_sequence=['yellow', 'green', 'blue', 'red'])

fig.update_traces(marker=dict(size=5, line=dict(width=2, color='DarkSlateGrey')), selector=dict(mode='markers'))

# Hide the color bar
fig.update_layout(coloraxis_showscale=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="8dbedd28-88a7-411f-bacd-22f4b56bdbe2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8dbedd28-88a7-411f-bacd-22f4b56bdbe2")) {                    Plotly.newPlot(                        "8dbedd28-88a7-411f-bacd-22f4b56bdbe2",                        [{"customdata":[["end"],["artist"],["group"],["blue"],["action"],["computer"],["curve"],["dog"],["client"],["know"],["use"],["computer"],["consciousness"],["game"],["problem"],["say"],["post"],["fake"],["tech"],["lead"],["question"],["people"],["aspiration"],["level"],["silly"],["percentage"],["loose"],["think"],["exchange"],["creation"],["replace"],["want"],["lose"],["destructive"],["research"],["time"],["good"],["modify"],["plus"],["thing"],["instant"],["try"],["human"],["yes"],["post"],["want"],["growth"],["maybe"],["know"],["room"],["actually"],["child"],["thing"],["free"],["clue"],["maybe"],["know"],["automatic"],["sound"],["people"],["far"],["advanced"],["steady"],["happen"],["think"],["website"],["manner"],["huge"],["look"],["need"],["execute"],["scary"],["actual"],["yes"],["one"],["turn"],["due"],["go"],["produce"],["game"],["enforce"],["increase"],["first"],["client"],["one"],["additional"],["think"],["tamper"],["new"],["communicate"],["obvious"],["go"],["dangerous"],["mile"],["musician"],["impact"],["fully"],["currently"],["way"],["get"],["feeling"],["say"],["year"],["intelligence"],["get"],["produce"],["harm"],["see"],["tech"],["change"],["make"],["draw"],["issue"],["doubt"],["disk"],["single"],["work"],["billionaire"],["come"],["develop"],["tax"],["detection"],["art"],["creative"],["change"],["direction"],["talk"],["heart"],["new"],["say"],["contact"],["people"],["accelerate"],["stand"],["sense"],["link"],["traditional"],["community"],["cool"],["want"],["like"],["people"],["filter"],["nurse"],["alien"],["even"],["kill"],["fight"],["word"],["manipulate"],["want"],["concern"],["trade"],["use"],["box"],["call"],["invention"],["make"],["climate"],["cocktail"],["position"],["make"],["policy"],["order"],["even"],["alone"],["watch"],["maybe"],["go"],["smart"],["kill"],["artistic"],["hurt"],["rely"],["code"],["see"],["pattern"],["control"],["like"],["accurate"],["information"],["theory"],["want"],["year"],["human"],["interest"],["internet"],["happen"],["remember"],["mind"],["essentially"],["system"],["famous"],["keep"],["mass"],["manual"],["concern"],["thought"],["arm"],["hand"],["way"],["right"],["embrace"],["area"],["commit"],["afraid"],["concentrate"],["return"],["work"],["famous"],["reason"],["powerful"],["use"],["punish"],["stop"],["crazy"],["group"],["border"],["agency"],["regular"],["express"],["problem"],["letter"],["software"],["film"],["purpose"],["relax"],["ignore"],["walk"],["assume"],["remove"],["genius"],["oh"],["passion"],["hike"],["frame"],["want"],["thing"],["reach"],["pump"],["try"],["widely"],["human"],["art"],["sentence"],["use"],["would"],["ask"],["make"],["security"],["application"],["well"],["year"],["like"],["feed"],["speed"],["realm"],["example"],["available"],["fine"],["fully"],["software"],["hope"],["loss"],["figure"],["style"],["executive"],["clipper"],["create"],["ability"],["cognitive"],["red"],["stuff"],["like"],["abuse"],["respond"],["even"],["way"],["pull"],["suppose"],["rational"],["little"],["dummy"],["emotional"],["word"],["kick"],["alive"],["ultimately"],["prefer"],["algorithm"],["thing"],["incredibly"],["use"],["get"],["seriously"],["memory"],["example"],["like"],["safe"],["industrial"],["logo"],["force"],["scar"],["program"],["generate"],["lazy"],["thing"],["people"],["high"],["work"],["stack"],["ask"],["system"],["liability"],["improvement"],["reach"],["train"],["progress"],["bad"],["output"],["case"],["share"],["see"],["respond"],["tool"],["signa ...

# %%
# Saving the 3D scatter plot as an HTML file
fig.write_html('/work/GitHub_ML_Deepnote/Machine Learning/4. VAD/vad_3d_plot.html')

# %% [markdown]
# ### New visual w. proper clusters

# %%
# Sample data
corpus_vad_s = corpus_vad.sample(2000)

# Convert 'Cluster' column to string
corpus_vad_s['Cluster'] = corpus_vad_s['Cluster'].astype(str)

fig = px.scatter_3d(corpus_vad_s, x='valence', y='arousal', z='dominance', color='Cluster', hover_data=[corpus_vad_s.index],
                    color_discrete_sequence=px.colors.sequential.Rainbow)

fig.update_traces(marker=dict(size=5, line=dict(width=2, color='DarkSlateGrey')), selector=dict(mode='markers'))

# Hide the color bar
fig.update_layout(coloraxis_showscale=False)

# Add legend
fig.update_layout(showlegend=True)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="3f3ace7a-c387-4a05-9dea-6558af38e0c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f3ace7a-c387-4a05-9dea-6558af38e0c7")) {                    Plotly.newPlot(                        "3f3ace7a-c387-4a05-9dea-6558af38e0c7",                        [{"customdata":[["like"],["way"],["output"],["friend"],["completely"],["feed"],["hand"],["practice"],["robot"],["please"],["ensure"],["tomato"],["completely"],["know"],["robot"],["get"],["keep"],["see"],["rabbit"],["event"],["well"],["idea"],["like"],["start"],["art"],["get"],["feel"],["safe"],["tree"],["dream"],["get"],["pure"],["get"],["image"],["develop"],["surely"],["person"],["cup"],["house"],["tool"],["like"],["reason"],["get"],["safe"],["add"],["know"],["handle"],["acceptance"],["person"],["learn"],["view"],["say"],["make"],["sky"],["access"],["read"],["new"],["answer"],["star"],["picture"],["wheel"],["dig"],["plenty"],["capable"],["know"],["position"],["stage"],["sure"],["item"],["present"],["dream"],["keep"],["say"],["sprinkle"],["kind"],["rabbit"],["way"],["act"],["one"],["one"],["make"],["like"],["tool"],["humanity"],["capability"],["see"],["post"],["see"],["allow"],["local"],["like"],["one"],["surely"],["sense"],["consciousness"],["new"],["include"],["hand"],["know"],["accept"],["practice"],["personal"],["one"],["likely"],["well"],["software"],["reply"],["image"],["may"],["stage"],["tool"],["get"],["content"],["allow"],["fact"],["dream"],["ensure"],["researcher"],["do"],["identify"],["get"],["start"],["community"],["robot"],["new"],["art"],["answer"],["know"],["solely"],["watch"],["highlight"],["generate"],["get"],["like"],["new"],["coordinate"],["get"],["source"],["capability"],["know"],["author"],["driver"],["tend"],["translation"],["good"],["imagine"],["art"],["yes"],["like"],["way"],["autonomy"],["near"],["fine"],["like"],["page"],["content"],["send"],["automobile"],["intellect"],["imagine"],["may"],["thought"],["eye"],["make"],["lot"],["beneficial"],["software"],["feel"],["kind"],["art"],["know"],["house"],["get"],["way"],["word"],["night"],["see"],["decide"],["thought"],["home"],["make"],["feel"],["idea"],["assist"],["get"],["like"],["do"],["post"],["land"],["add"],["art"],["talent"],["one"],["one"],["like"],["style"],["make"],["one"],["kind"],["develop"],["build"],["nature"],["content"],["potential"],["fact"],["start"],["like"],["one"],["word"],["establish"],["reality"],["new"],["new"],["profession"],["actor"],["find"],["like"],["well"],["quality"],["level"],["care"],["like"],["mind"],["see"],["know"],["like"],["please"],["complete"],["specific"],["sell"],["likely"],["appear"],["like"],["consistent"],["actually"],["let"],["know"],["actually"],["yes"],["good"],["completely"],["cultural"],["agree"],["art"],["idea"],["consent"],["voice"],["nature"],["island"],["new"],["tool"],["get"],["way"],["see"],["content"],["get"],["tech"],["know"],["reason"],["like"],["let"],["artist"],["accessible"],["composition"],["sure"],["essential"],["stable"],["lot"],["get"],["kind"],["see"],["idea"],["artistic"],["direct"],["hand"],["sentiment"],["continue"],["level"],["driver"],["see"],["production"],["like"],["family"],["like"],["one"],["conscious"],["post"],["light"],["specific"],["actually"],["make"],["thank"],["know"],["person"],["make"],["get"],["engineer"],["acceptable"],["artist"],["make"],["artist"],["moment"],["dig"],["fact"],["sort"],["way"],["decide"],["word"],["good"],["actually"],["see"],["personal"],["see"],["plan"],["yes"],["know"],["self"],["save"],["reality"],["say"],["film"],["eye"],["like"],["harvest"],["pass"],["lot"],["sense"],["naturally"],["write"],["threshold"],["potential"],["post"],["see"],["sort"],["get"],["know"],["learn"],["lot"],["natural"],["methodology"],["say"] ...

# %%
# Sample data
corpus_vad_s = corpus_vad.sample(1000)

# Plot 1: Valence vs Dominance
fig1 = px.scatter(corpus_vad_s, x='valence', y='dominance', color='Cluster', hover_data=[corpus_vad_s.index],
                  color_discrete_sequence=['yellow', 'green', 'blue', 'red'])

fig1.update_traces(marker=dict(size=5, line=dict(width=0)), selector=dict(mode='markers'))

# Plot 2: Arousal vs Valence
fig2 = px.scatter(corpus_vad_s, x='arousal', y='valence', color='Cluster', hover_data=[corpus_vad_s.index],
                  color_discrete_sequence=['yellow', 'green', 'blue', 'red'])

fig2.update_traces(marker=dict(size=5, line=dict(width=0)), selector=dict(mode='markers'))

# Plot 3: Arousal vs Dominance
fig3 = px.scatter(corpus_vad_s, x='arousal', y='dominance', color='Cluster', hover_data=[corpus_vad_s.index],
                  color_discrete_sequence=['yellow', 'green', 'blue', 'red'])

fig3.update_traces(marker=dict(size=5, line=dict(width=0)), selector=dict(mode='markers'))

# Show the plots
fig1.show()
fig2.show()
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="e6e5b234-37b0-4c3a-ab33-9bcaecf1800b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6e5b234-37b0-4c3a-ab33-9bcaecf1800b")) {                    Plotly.newPlot(                        "e6e5b234-37b0-4c3a-ab33-9bcaecf1800b",                        [{"customdata":[["capability"],["make"],["witness"],["follow"],["fake"],["design"],["would"],["mad"],["want"],["loop"],["bad"],["heritage"],["great"],["likely"],["far"],["person"],["potential"],["stuff"],["specifically"],["belief"],["human"],["intelligence"],["fact"],["patch"],["base"],["control"],["effect"],["right"],["swallow"],["realize"],["question"],["evidence"],["make"],["understand"],["would"],["represent"],["approach"],["perform"],["may"],["use"],["people"],["money"],["solve"],["world"],["go"],["power"],["respect"],["read"],["theory"],["prove"],["get"],["space"],["crime"],["future"],["class"],["feature"],["nutrition"],["thing"],["fetch"],["example"],["accord"],["help"],["concept"],["world"],["would"],["minister"],["absolutely"],["get"],["lab"],["product"],["characterize"],["game"],["new"],["boat"],["argument"],["smart"],["merely"],["knowledge"],["power"],["group"],["communication"],["first"],["long"],["period"],["thing"],["encounter"],["biological"],["function"],["alive"],["get"],["intelligent"],["replace"],["major"],["care"],["even"],["design"],["conscious"],["current"],["exploration"],["harmful"],["propose"],["ask"],["require"],["short"],["set"],["little"],["produce"],["fight"],["easily"],["trick"],["thing"],["sense"],["luxury"],["need"],["moral"],["executive"],["turn"],["system"],["awareness"],["evolutionary"],["talk"],["like"],["prompt"],["brain"],["apart"],["ridiculous"],["put"],["time"],["turn"],["capability"],["opponent"],["creativity"],["money"],["likelihood"],["tech"],["like"],["create"],["control"],["human"],["well"],["people"],["approach"],["consciousness"],["indifferent"],["sale"],["operate"],["force"],["say"],["long"],["theory"],["respond"],["term"],["yes"],["human"],["way"],["people"],["production"],["say"],["follow"],["people"],["human"],["digital"],["know"],["death"],["worker"],["super"],["admit"],["fundamental"],["point"],["see"],["create"],["different"],["think"],["order"],["scientific"],["create"],["thing"],["anticipate"],["danger"],["bad"],["pharmaceutical"],["roman"],["branch"],["convention"],["miss"],["fundamental"],["language"],["argument"],["even"],["notion"],["point"],["create"],["rich"],["kind"],["instruction"],["dazzle"],["possible"],["effect"],["problem"],["rate"],["space"],["would"],["therapist"],["world"],["single"],["worry"],["hand"],["problem"],["human"],["solution"],["would"],["base"],["job"],["certain"],["new"],["manipulate"],["need"],["guide"],["long"],["land"],["great"],["suppose"],["conversation"],["job"],["portion"],["replace"],["logic"],["hardware"],["artificial"],["create"],["narrative"],["way"],["call"],["law"],["reasonable"],["need"],["base"],["step"],["game"],["hook"],["specific"],["time"],["free"],["implication"],["guess"],["stand"],["mean"],["even"],["point"],["weapon"],["create"],["sort"],["appreciate"],["way"],["definitely"],["trust"],["entire"],["lot"],["ask"],["industry"],["try"],["primary"],["chess"],["property"],["express"],["plain"],["potentially"],["possible"],["demand"],["destroy"],["enact"],["selection"],["lump"],["strategic"],["know"],["text"],["think"],["consciousness"],["twice"],["drug"],["happen"],["internet"],["actually"],["thing"],["intelligence"],["check"],["idea"],["magical"],["think"],["make"],["see"],["even"],["money"],["actor"],["start"],["memory"],["work"],["word"],["even"],["problem"],["know"],["able"],["competition"],["end"],["entity"],["today"],["special"],["requirement"],["well"],["thing"],["concern"],["lot"],["s ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="7e5efe20-054d-4cd6-af12-61a51af83f26" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e5efe20-054d-4cd6-af12-61a51af83f26")) {                    Plotly.newPlot(                        "7e5efe20-054d-4cd6-af12-61a51af83f26",                        [{"customdata":[["capability"],["make"],["witness"],["follow"],["fake"],["design"],["would"],["mad"],["want"],["loop"],["bad"],["heritage"],["great"],["likely"],["far"],["person"],["potential"],["stuff"],["specifically"],["belief"],["human"],["intelligence"],["fact"],["patch"],["base"],["control"],["effect"],["right"],["swallow"],["realize"],["question"],["evidence"],["make"],["understand"],["would"],["represent"],["approach"],["perform"],["may"],["use"],["people"],["money"],["solve"],["world"],["go"],["power"],["respect"],["read"],["theory"],["prove"],["get"],["space"],["crime"],["future"],["class"],["feature"],["nutrition"],["thing"],["fetch"],["example"],["accord"],["help"],["concept"],["world"],["would"],["minister"],["absolutely"],["get"],["lab"],["product"],["characterize"],["game"],["new"],["boat"],["argument"],["smart"],["merely"],["knowledge"],["power"],["group"],["communication"],["first"],["long"],["period"],["thing"],["encounter"],["biological"],["function"],["alive"],["get"],["intelligent"],["replace"],["major"],["care"],["even"],["design"],["conscious"],["current"],["exploration"],["harmful"],["propose"],["ask"],["require"],["short"],["set"],["little"],["produce"],["fight"],["easily"],["trick"],["thing"],["sense"],["luxury"],["need"],["moral"],["executive"],["turn"],["system"],["awareness"],["evolutionary"],["talk"],["like"],["prompt"],["brain"],["apart"],["ridiculous"],["put"],["time"],["turn"],["capability"],["opponent"],["creativity"],["money"],["likelihood"],["tech"],["like"],["create"],["control"],["human"],["well"],["people"],["approach"],["consciousness"],["indifferent"],["sale"],["operate"],["force"],["say"],["long"],["theory"],["respond"],["term"],["yes"],["human"],["way"],["people"],["production"],["say"],["follow"],["people"],["human"],["digital"],["know"],["death"],["worker"],["super"],["admit"],["fundamental"],["point"],["see"],["create"],["different"],["think"],["order"],["scientific"],["create"],["thing"],["anticipate"],["danger"],["bad"],["pharmaceutical"],["roman"],["branch"],["convention"],["miss"],["fundamental"],["language"],["argument"],["even"],["notion"],["point"],["create"],["rich"],["kind"],["instruction"],["dazzle"],["possible"],["effect"],["problem"],["rate"],["space"],["would"],["therapist"],["world"],["single"],["worry"],["hand"],["problem"],["human"],["solution"],["would"],["base"],["job"],["certain"],["new"],["manipulate"],["need"],["guide"],["long"],["land"],["great"],["suppose"],["conversation"],["job"],["portion"],["replace"],["logic"],["hardware"],["artificial"],["create"],["narrative"],["way"],["call"],["law"],["reasonable"],["need"],["base"],["step"],["game"],["hook"],["specific"],["time"],["free"],["implication"],["guess"],["stand"],["mean"],["even"],["point"],["weapon"],["create"],["sort"],["appreciate"],["way"],["definitely"],["trust"],["entire"],["lot"],["ask"],["industry"],["try"],["primary"],["chess"],["property"],["express"],["plain"],["potentially"],["possible"],["demand"],["destroy"],["enact"],["selection"],["lump"],["strategic"],["know"],["text"],["think"],["consciousness"],["twice"],["drug"],["happen"],["internet"],["actually"],["thing"],["intelligence"],["check"],["idea"],["magical"],["think"],["make"],["see"],["even"],["money"],["actor"],["start"],["memory"],["work"],["word"],["even"],["problem"],["know"],["able"],["competition"],["end"],["entity"],["today"],["special"],["requirement"],["well"],["thing"],["concern"],["lot"],["s ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="f04563f2-7d8c-483f-8f60-29593d2ef68c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f04563f2-7d8c-483f-8f60-29593d2ef68c")) {                    Plotly.newPlot(                        "f04563f2-7d8c-483f-8f60-29593d2ef68c",                        [{"customdata":[["capability"],["make"],["witness"],["follow"],["fake"],["design"],["would"],["mad"],["want"],["loop"],["bad"],["heritage"],["great"],["likely"],["far"],["person"],["potential"],["stuff"],["specifically"],["belief"],["human"],["intelligence"],["fact"],["patch"],["base"],["control"],["effect"],["right"],["swallow"],["realize"],["question"],["evidence"],["make"],["understand"],["would"],["represent"],["approach"],["perform"],["may"],["use"],["people"],["money"],["solve"],["world"],["go"],["power"],["respect"],["read"],["theory"],["prove"],["get"],["space"],["crime"],["future"],["class"],["feature"],["nutrition"],["thing"],["fetch"],["example"],["accord"],["help"],["concept"],["world"],["would"],["minister"],["absolutely"],["get"],["lab"],["product"],["characterize"],["game"],["new"],["boat"],["argument"],["smart"],["merely"],["knowledge"],["power"],["group"],["communication"],["first"],["long"],["period"],["thing"],["encounter"],["biological"],["function"],["alive"],["get"],["intelligent"],["replace"],["major"],["care"],["even"],["design"],["conscious"],["current"],["exploration"],["harmful"],["propose"],["ask"],["require"],["short"],["set"],["little"],["produce"],["fight"],["easily"],["trick"],["thing"],["sense"],["luxury"],["need"],["moral"],["executive"],["turn"],["system"],["awareness"],["evolutionary"],["talk"],["like"],["prompt"],["brain"],["apart"],["ridiculous"],["put"],["time"],["turn"],["capability"],["opponent"],["creativity"],["money"],["likelihood"],["tech"],["like"],["create"],["control"],["human"],["well"],["people"],["approach"],["consciousness"],["indifferent"],["sale"],["operate"],["force"],["say"],["long"],["theory"],["respond"],["term"],["yes"],["human"],["way"],["people"],["production"],["say"],["follow"],["people"],["human"],["digital"],["know"],["death"],["worker"],["super"],["admit"],["fundamental"],["point"],["see"],["create"],["different"],["think"],["order"],["scientific"],["create"],["thing"],["anticipate"],["danger"],["bad"],["pharmaceutical"],["roman"],["branch"],["convention"],["miss"],["fundamental"],["language"],["argument"],["even"],["notion"],["point"],["create"],["rich"],["kind"],["instruction"],["dazzle"],["possible"],["effect"],["problem"],["rate"],["space"],["would"],["therapist"],["world"],["single"],["worry"],["hand"],["problem"],["human"],["solution"],["would"],["base"],["job"],["certain"],["new"],["manipulate"],["need"],["guide"],["long"],["land"],["great"],["suppose"],["conversation"],["job"],["portion"],["replace"],["logic"],["hardware"],["artificial"],["create"],["narrative"],["way"],["call"],["law"],["reasonable"],["need"],["base"],["step"],["game"],["hook"],["specific"],["time"],["free"],["implication"],["guess"],["stand"],["mean"],["even"],["point"],["weapon"],["create"],["sort"],["appreciate"],["way"],["definitely"],["trust"],["entire"],["lot"],["ask"],["industry"],["try"],["primary"],["chess"],["property"],["express"],["plain"],["potentially"],["possible"],["demand"],["destroy"],["enact"],["selection"],["lump"],["strategic"],["know"],["text"],["think"],["consciousness"],["twice"],["drug"],["happen"],["internet"],["actually"],["thing"],["intelligence"],["check"],["idea"],["magical"],["think"],["make"],["see"],["even"],["money"],["actor"],["start"],["memory"],["work"],["word"],["even"],["problem"],["know"],["able"],["competition"],["end"],["entity"],["today"],["special"],["requirement"],["well"],["thing"],["concern"],["lot"],["s ...

# %%
# Save the plots as HTML files
fig1.write_html('/work/GitHub_ML_Deepnote/Machine Learning/4. VAD/vad_plot_valence_dominance.html')
fig2.write_html('/work/GitHub_ML_Deepnote/Machine Learning/4. VAD/vad_plot_arousal_valence.html')
fig3.write_html('/work/GitHub_ML_Deepnote/Machine Learning/4. VAD/vad_plot_arousal_dominance.html')

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f64215d6-debc-46bd-b273-63565459a66d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
