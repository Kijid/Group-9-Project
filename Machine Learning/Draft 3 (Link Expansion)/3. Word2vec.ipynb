# %%
# !pip install gensim==4.3.2
# Out:
# Collecting gensim==4.3.2
#   Downloading gensim-4.3.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.6/26.6 MB 63.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.5 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (1.23.4)
# Requirement already satisfied: smart-open>=1.8.1 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (5.2.1)
# Requirement already satisfied: scipy>=1.7.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from gensim==4.3.2) (1.9.3)
# Installing collected packages: gensim
# Successfully installed gensim-4.3.2
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pickle
import pandas as pd
import nltk
import gensim

import numpy as np

import gensim
from gensim import corpora
from gensim.corpora import Dictionary
from gensim.models.ldamodel import LdaModel
from gensim.models.coherencemodel import CoherenceModel
from gensim.utils import simple_preprocess
import sklearn
from sklearn.decomposition import PCA
from sklearn.cluster import AgglomerativeClustering
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.metrics import silhouette_samples
from sklearn.cluster import AffinityPropagation
from scipy.spatial import distance
from sklearn.feature_extraction.text import CountVectorizer

# Visualization & topic modelling
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
# !pip install --user plotly
import plotly
import plotly.express as px

# utility modules
from ast import literal_eval

# %%
word_level_df = pd.read_csv('/work/GitHub_ML_Deepnote/Machine Learning/2. Cleaning & Pre-processing/word_level_df.csv', encoding='utf-8', index_col=0)
sentence_level_df = pd.read_csv('/work/GitHub_ML_Deepnote/Machine Learning/2. Cleaning & Pre-processing/sentence_level_df.csv',  encoding='utf-8', index_col = 0)

# %%
# Extract lemmas from the 'lemmas' column in word_level_df
corpus_words = [literal_eval(lemmas) for lemmas in word_level_df['lemmas'].values]

# Save corpus_words as a pickle file
with open('/work/GitHub_ML_Deepnote/Machine Learning/3. Word2vec /corpus_words.pkl', 'wb') as file:
    pickle.dump(corpus_words, file)

# %%
corpus_model = gensim.models.Word2Vec(corpus_words, min_count= 20, vector_size = 300)

# %%
corpus_model.wv['fear']
# Out:
# array([ 8.94353352e-03,  2.36503229e-01, -8.85442421e-02,  1.15521131e-02,
#         9.92611423e-02, -2.69824207e-01,  8.42189491e-02,  3.23708266e-01,
#         1.31152004e-01, -9.74862743e-03, -7.39471465e-02, -1.45294219e-01,
#         1.00271113e-01,  6.83948305e-03, -1.03300996e-01, -2.27909479e-02,
#         1.61590993e-01, -1.01880748e-02,  2.84467489e-02, -2.77029220e-02,
#        -1.49436399e-01,  5.82357496e-03,  1.29116848e-01, -1.80539337e-03,
#         9.43019614e-02,  8.71886387e-02, -2.75307655e-01, -7.11861998e-02,
#        -9.94647220e-02, -7.78351426e-02,  8.28829333e-02, -1.12581193e-01,
#        -4.15033139e-02,  5.80999665e-02, -5.42117171e-02,  4.28812392e-02,
#        -3.80839668e-02, -2.12704569e-01, -1.78387333e-02, -1.12450251e-03,
#        -1.19679399e-01,  1.09884538e-01, -6.33542761e-02, -6.93911463e-02,
#         2.16481864e-01,  1.24485649e-01, -3.03465892e-02,  9.30887163e-02,
#        -5.84963076e-02,  1.93374783e-01,  5.80676720e-02, -1.64354201e-02,
#        -6.14184625e-02, -4.66179624e-02, -1.02377310e-01,  2.16654927e-01,
#         9.01845768e-02, -5.54344170e-02,  3.40918265e-02,  1.16707824e-01,
#        -2.95482203e-02, -5.66104725e-02, -4.26015258e-02,  6.49798512e-02,
#         6.31484482e-03,  1.38847157e-01, -3.31007503e-03,  7.19537064e-02,
#        -9.33514908e-02, -2.81546302e-02, -1.88401602e-02,  4.16011512e-02,
#         1.28970504e-01, -1.57569170e-01, -6.09177016e-02,  1.25746503e-01,
#        -2.14757681e-01,  1.21928751e-01, -1.39849350e-01,  6.75383657e-02,
#        -8.68642479e-02, -1.13944538e-01,  9.26503912e-02,  2.65310228e-01,
#         9.83438045e-02, -4.31497321e-02, -1.80836171e-01,  1.08888489e-03,
#         2.05458432e-01,  4.74577397e-02,  1.90360948e-01, -1.70588717e-01,
#         1.01071730e-01,  4.45052348e-02,  1.87516376e-01,  1.68811440e-01,
#         1.50877833e-01, -3.79804373e-02, -6.08342998e-02,  1.56619206e-01,
#        -2.03183722e-02, -6.01724498e-02,  1.83798239e-01, -3.07671186e-02,
#         5.22145070e-02, -3.58942673e-02,  5.86641282e-02,  4.37315553e-02,
#        -1.21208109e-01,  1.42338304e-02, -1.38843387e-01,  5.69825340e-03,
#        -6.77054822e-02,  1.58325791e-01,  1.78845063e-01,  2.23277640e-02,
#        -2.70208996e-02,  3.94860283e-02,  1.46175295e-01, -1.15094274e-01,
#         1.98237330e-01,  5.45102730e-02,  7.11846501e-02,  1.59518179e-02,
#        -1.13052696e-01, -2.86129881e-02,  1.48310587e-01, -1.44503757e-01,
#        -1.14665786e-02,  9.53443944e-02,  8.02355632e-02,  2.56837815e-01,
#         7.97689855e-02, -1.99153692e-01,  7.61092901e-02,  1.24997787e-01,
#        -6.08614571e-02, -1.70401454e-01, -1.02363184e-01, -2.10312128e-01,
#        -1.03920996e-02, -1.57238320e-01,  1.03889622e-01,  1.25491530e-01,
#         8.29882622e-02, -1.89084500e-01, -2.04777926e-01,  3.20239998e-02,
#         8.79327208e-03, -1.44014999e-01,  4.67463844e-02, -3.24077487e-01,
#        -1.93003893e-01, -8.01607743e-02,  1.04819186e-01,  1.12646967e-01,
#        -5.29773124e-02, -1.99253142e-01,  5.19062988e-02,  1.73437029e-01,
#        -2.01483499e-02,  1.08702235e-01, -2.50485212e-01,  8.84360820e-02,
#        -1.49361596e-01,  1.26938969e-01,  1.91997066e-02,  7.56172240e-02,
#         5.92083782e-02,  2.81709224e-01, -4.96598668e-02,  1.00509606e-01,
#         5.91613688e-02,  7.88812786e-02, -1.16691157e-01,  5.93043864e-02,
#         1.80358276e-01, -1.72965512e-01, -6.36222512e-02, -1.64803173e-02,
#        -6.82467669e-02,  1.42675877e-01, -4.88986894e-02, -7.75645226e-02,
#         6.92074150e-02,  7.78936082e-03,  6.63125068e-02,  1.85181558e-01,
#         2.82078632e-04, -1.78172231e-01,  4.58780639e-02, -3.63143124e-02,
#        -1.97453126e-01, -2.21405104e-02,  5.12962490e-02, -1.32335722e-01,
#        -8.83582234e-03, -1.45821840e-01,  8.55833516e-02,  7.58824125e-02,
#        -2.08106831e-01,  6.47525340e-02,  1.67600308e-02, -1.74076274e-01,
#        -4.15723994e-02,  5.42926090e-03, -2.58041564e-02, -1.88812036e-02,
#        -3.42242084e-02,  4.07926382e-05,  9.80071276e-02, -1.15658365e-01,
#        -1.09536357e-01,  4.34180908e-02,  8.01598877e-02, -2.09148169e-01,
#        -1.07737027e-01, -3.20470750e-01, -2.53527611e-01, -9.16847214e-02,
#         1.92092940e-01,  9.67373792e-03, -1.52690813e-01, -4.40173782e-02,
#        -1.26454204e-01, -8.05619508e-02,  9.80813503e-02, -4.15272154e-02,
#        -1.34753436e-01,  1.40908733e-02,  1.52940810e-01, -1.29967541e-01,
#        -1.83297768e-01,  2.99755987e-02, -9.36711803e-02,  8.65837485e-02,
#        -1.48822647e-02,  2.99697984e-02,  2.18866114e-02, -3.19225490e-01,
#         8.65366831e-02, -5.94096109e-02, -1.05797745e-01,  5.09745479e-02,
#        -4.75080758e-02, -2.21936136e-01, -3.13239247e-02,  1.70885041e-01,
#         4.03878242e-02,  2.21543998e-01, -1.68242641e-02,  1.23770989e-01,
#         1.17514580e-01,  5.48286289e-02, -2.72028327e-01, -1.91494614e-01,
#         2.32996240e-01,  1.04433924e-01, -2.45655715e-01, -1.13915265e-01,
#         1.04079545e-01,  1.50258407e-01, -5.51650822e-02, -1.51786268e-01,
#        -1.88324824e-01, -4.13244031e-02,  7.88925514e-02,  3.21711786e-02,
#        -1.80617735e-01, -5.90186892e-03, -8.64177793e-02, -3.09931580e-03,
#        -6.09251000e-02, -1.59686029e-01,  2.48648539e-01,  6.23819530e-02,
#         6.17149137e-02,  9.41803097e-04, -1.27042592e-01, -6.03780076e-02,
#         1.05795674e-01,  3.01904436e-02, -8.97130594e-02,  4.13983874e-02,
#        -2.59628184e-02, -3.70915905e-02, -2.17162430e-01,  1.14727080e-01,
#         5.77055886e-02,  1.85232610e-01, -1.18840057e-02,  2.10065752e-01,
#         1.38789520e-01,  1.90047640e-02,  1.61655933e-01,  9.32104513e-02,
#        -1.53596315e-03, -9.61326901e-03,  1.03864715e-01, -9.25448462e-02],
#       dtype=float32)

# %%
#Creating a dataframe out of the corpus to train the model and it's relative word vectors.
corpus_vocab = corpus_model.wv.index_to_key
corpus_vectors = [corpus_model.wv[i] for i in corpus_vocab]
corpus_df = pd.DataFrame(corpus_vectors)

#Needed for principle component analysis 
corpus_df.columns = [str(i) for i in corpus_df.columns]

# %%
# Concatinating - reducing the dimensionality of the data into 3 components so we can plot it & visualise it. 

pca = PCA(n_components = 3)
comps_1 = pca.fit_transform(corpus_vectors)
pc_df_1 = pd.DataFrame(data = comps_1, columns = ['Principal Component '+str(i) for i in range(1, comps_1.shape[1]+1)])
corpus_df = pd.concat([corpus_df, pc_df_1], axis = 1)
corpus_df.index = corpus_vocab

# %%
#Elbow method to identify number of clusters - this method indicates 2 as a good number.

#range being tested
inertia = []
K = range(1,10)

for k in K:
    kmeans = KMeans(n_clusters=k, random_state=0, n_init=10)
    kmeans.fit(corpus_vectors)
    inertia.append(kmeans.inertia_)
    
plt.figure(figsize=(10,6))
# sns.lineplot(x=K, y=inertia, marker='o')
plt.plot(K,inertia)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')
plt.xticks(np.arange(min(K), max(K)+1, 1.0))
plt.show()

# %%
#Silhoutte method to identify optimal amount of clusters. This method is indicating 5.

#range of clusters to test
range_n_clusters = range(2, 10)

# Converting dataframe to numpy array for clustering
X = np.array(corpus_df)

# Initialising list to store silhouette scores for each number of clusters
silhouette_scores = []

# Iterating over set range of clusters and calculating silhouette score
for n_clusters in range_n_clusters:
    kmeans = KMeans(n_clusters=n_clusters, random_state=0, n_init= 10)
    cluster_labels = kmeans.fit_predict(X)
    silhouette_avg = silhouette_score(X, cluster_labels)
    silhouette_scores.append(silhouette_avg)
    print("For n_clusters =", n_clusters, "The average silhouette_score is :", silhouette_avg)

# Plotting silhouette scores vs. number of clusters. A higher average silhouette score indicates better-defined clusters.
plt.plot(range_n_clusters, silhouette_scores)
plt.title("Silhouette scores vs. number of clusters")
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette score")
plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.6307611622257108
# For n_clusters = 3 The average silhouette_score is : 0.5775192337872456
# For n_clusters = 4 The average silhouette_score is : 0.530660301863647
# For n_clusters = 5 The average silhouette_score is : 0.45927785814345296
# For n_clusters = 6 The average silhouette_score is : 0.4322812770963018
# For n_clusters = 7 The average silhouette_score is : 0.41582058771727687
# For n_clusters = 8 The average silhouette_score is : 0.4038807882683853
# For n_clusters = 9 The average silhouette_score is : 0.3781815201351911

# %%
# Clustering our data to see what groups together

kmeans = KMeans(n_clusters=3, random_state=0, n_init= 10 ).fit(corpus_df)

#Adding relevant values to our dataframe
corpus_df['clusters_knn'] = [str(i) for i in kmeans.labels_]

# %%
#Dimension reduction visualised and categorised into clusters

fig = px.scatter_3d(
    corpus_df, 
    x='Principal Component 1', y='Principal Component 2', z='Principal Component 3',
    color='clusters_knn',
    hover_data = [corpus_df.index]
    )

fig.update_traces(marker=dict(size = 5, line=dict(width=2,color='DarkSlateGrey')), selector=dict(mode='markers'))
fig.show()

pd.set_option('display.max_rows', None)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.14.0.min.js"></script>                <div id="c59fb02b-a6c1-439f-a284-590dace800ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c59fb02b-a6c1-439f-a284-590dace800ca")) {                    Plotly.newPlot(                        "c59fb02b-a6c1-439f-a284-590dace800ca",                        [{"customdata":[["ai"],["people"],["like"],["make"],["think"],["get"],["human"],["use"],["go"],["dont"],["thing"],["would"],["work"],["one"],["say"],["well"],["even"],["could"],["job"],["im"],["know"],["need"],["see"],["time"],["way"],["take"],["year"],["u"],["thats"],["want"],["art"],["something"],["also"],["much"],["already"],["good"],["really"],["still"],["create"],["cant"],["youre"],["look"],["come"],["point"],["many"],["world"],["new"],["right"],["technology"],["lot"],["doesnt"],["give"],["learn"],["isnt"],["replace"],["understand"],["life"],["model"],["able"],["mean"],["bad"],["real"],["try"],["system"],["..."],["there"],["change"],["problem"],["artist"],["tool"],["design"],["fear"],["wont"],["happen"],["never"],["anything"],["might"],["machine"],["every"],["may"],["start"],["actually"],["someone"],["data"],["sure"],["without"],["stop"],["drive"],["agi"],["always"],["money"],["become"],["intelligence"],["power"],["feel"],["everyone"],["speed"],["seem"],["company"],["day"],["enough"],["end"],["computer"],["control"],["write"],["reason"],["talk"],["thought"],["idea"],["long"],["future"],["help"],["first"],["maybe"],["issue"],["robot"],["big"],["example"],["public"],["less"],["person"],["find"],["around"],["let"],["easy"],["video"],["ive"],["though"],["probably"],["believe"],["chatgpt"],["image"],["ask"],["government"],["tell"],["different"],["ever"],["tech"],["everything"],["law"],["keep"],["generate"],["part"],["level"],["goal"],["nothing"],["etc"],["great"],["far"],["fact"],["concern"],["theyre"],["base"],["information"],["put"],["camera"],["possible"],["fake"],["stuff"],["pretty"],["state"],["kind"],["internet"],["likely"],["call"],["yes"],["shit"],["society"],["place"],["another"],["imagine"],["post"],["hand"],["hard"],["run"],["general"],["development"],["yet"],["instead"],["matter"],["humanity"],["back"],["program"],["case"],["medium"],["potential"],["least"],["phone"],["train"],["designer"],["comment"],["value"],["since"],["care"],["anyone"],["literally"],["fine"],["lose"],["yeah"],["fuck"],["code"],["true"],["social"],["worry"],["consciousness"],["pay"],["arent"],["best"],["didnt"],["question"],["kill"],["police"],["else"],["mind"],["wrong"],["turn"],["process"],["next"],["gpt"],["car"],["industry"],["2"],["llm"],["do"],["large"],["risk"],["whole"],["set"],["either"],["read"],["agree"],["worried"],["result"],["experience"],["current"],["wouldnt"],["high"],["away"],["scenario"],["completely"],["business"],["source"],["whatever"],["watch"],["lol"],["live"],["little"],["cause"],["exist"],["consider"],["danger"],["game"],["whats"],["require"],["ability"],["free"],["dangerous"],["two"],["improve"],["self"],["sound"],["answer"],["today"],["trust"],["automate"],["exactly"],["content"],["hope"],["software"],["soon"],["brain"],["bit"],["actual"],["limit"],["evidence"],["last"],["almost"],["decade"],["word"],["1"],["digital"],["ago"],["research"],["surveillance"],["scar"],["language"],["old"],["amount"],["field"],["build"],["scary"],["solve"],["guy"],["text"],["others"],["produce"],["lead"],["show"],["increase"],["id"],["worker"],["na"],["google"],["similar"],["number"],["ill"],["especially"],["interest"],["skill"],["however"],["month"],["basically"],["graphic"],["opinion"],["threat"],["training"],["prompt"],["bot"],["eventually"],["10"],["cost"],["break"],["due"],["type"],["sense"],["access"],["faster"],["continue"],["creative"],["resource"],["simply"],["small"],["powerful"],["gon"],["ne ...

# %%
# Save the 3D scatter plot as an HTML file
fig.write_html('/work/GitHub_ML_Deepnote/Machine Learning/3. Word2vec /scatter_plot_3d.html')

# %% [markdown]
# ### Using model (will be better once more data is added)

# %%
corpus_model.wv.most_similar(['future'])
# Out:
# [('truly', 0.9996113181114197),
#  ('destroy', 0.9996103048324585),
#  ('role', 0.9995893836021423),
#  ('fully', 0.999586284160614),
#  ('reality', 0.9995859265327454),
#  ('important', 0.9995856881141663),
#  ('must', 0.9995757937431335),
#  ('sentient', 0.9995752573013306),
#  ('safe', 0.9995743036270142),
#  ('..', 0.9995728135108948)]

# %%
corpus_model.wv.similarity("fear", "future")
# Out:
# 0.9983153

# %%
corpus_model.wv.similarity("asi", "future")
# Out:
# 0.99936575

# %%
corpus_model.wv.doesnt_match(['crisis',"fear", "asi", "good", "solution"])
# Out:
# 'fear'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=f64215d6-debc-46bd-b273-63565459a66d' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
